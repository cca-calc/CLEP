# %% [markdown]
# # The Mean Value Theorem (MVT) (Existence Type Theorem)
#
# ## 1. Statement of the Mean Value Theorem
#
# Let $f$ be a function that is:
#
# 1. **Continuous** on the closed interval $[a,b]$
# 2. **Differentiable** on the open interval $(a,b)$
#
# Then there **exists** at least one point $c$ in $(a,b)$ such that:
#
#
# $f'(c) = \frac{f(b) - f(a)}{b - a}$
#
#
# This means that at some point, the instantaneous rate of change equals the average rate of change over the interval

# %% [markdown]
# ## Example 1: Algebraic function.
# <table>
#   <tr>
#     <td style="vertical-align:top; width:50%;">
#
# Let $f(x) = x^2$ on $[1,4]$.
#
# - $f(1) = 1$
# - $f(4) = 16$
#
# Compute the average rate of change over $[1,4]$.
#
# $\frac{f(4) - f(1)}{4 - 1} = \frac{16 - 1}{3} = 5$
#
# Compute the derivative:
#
# $
# f'(x) = 2x
# $
#
# Find the point on the curve where $2x = 5$:
#
# $
# x = \frac{5}{2}
# $
#     </td>
#     <td style="vertical-align:top; text-align:right;">
#       <img src="mvt_1.png" style="max-width:772px;">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Example 2: Trigonometric function
# <table>
#   <tr>
#     <td style="vertical-align:top; width:50%;">
#
# Let $f(x) = \sin x$ on $[0, \pi]$.
# - $f(0) = 0$
# - $f(\pi) = 0$
#
# Compute the average rate of change over $[0, \pi]$:
#
# $
# \frac{0 - 0}{\pi - 0} = 0
# $
#
# Compute the derivative:
# $
# f'(x) = \cos x
# $
#
# Find the point one the curve where $\cos c = 0$:
#
# $
# c = \frac{\pi}{2}
# $
#      </td>
#      <td style="vertical-align:top; text-align:right;">
#        <img src="mvt_2.png" style="max-width:772px;">
#      </td>
#   </tr>
# </table>

# %% [markdown]
# ## Example 3: Function with two solutions on an interval.
#
# <table>
#   <tr>
#     <td style="vertical-align:top; width:50%;">
#
# Derivative:
#
# Let $f(x) = x^3$ on $[-2, 2]$.
#
# - $f(-2) = -8$
# - $f(2) = 8$
#
# Compute the average rate of change over $[-2, 2]$:
#
# $
# \frac{8 - (-8)}{2 - (-2)} = 16/4 = 4
# $
#
# Compute the derivative:
#
# $
# f'(x) = 3x^2
# $
#
# Find the point one the curve where $3x^2 = 4$:
#
# $
# c = \pm \frac{2}{\sqrt{3}}
# $
# $ $
#     </td>
#     <td style="vertical-align:top; text-align:right;">
#       <img src="mvt_3.png" style="max-width:772px;">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## Example 4: Showing a function is increasing
#
# Let $f(x) = x^3$ on any interval.
#
# Derivative:
#
# $
# f'(x) = 3x^2 \ge 0
# $
#
# For any $a < b$:
#
# $
# f(b) - f(a) = f'(c)(b - a) = 3c^2(b - a) \ge 0
# $
#
# Thus $f$ is increasing everywhere.
