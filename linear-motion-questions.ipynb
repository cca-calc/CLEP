# %% [markdown]
# ## CLEP Practice Questions: Position, Velocity, Acceleration Generated by GPT 5.1
#
#
# ### Question 1.
#
# If $s(t)$ is position and $v(t)=s'(t)$, what does $v(t)$ represent?
#
# A. Total distance
# B. Instantaneous velocity
# C. Average velocity
# D. Acceleration
#
# ---
#
# ### Question 2.
#
# If $v(t)=s'(t)$ and $v(t)>0$ on an interval, the object is:
#
# A. Moving backward
# B. Moving forward
# C. Not moving
# D. Slowing down
#
# ---
#
# ### Question 3.
#
# Acceleration is defined as:
#
# A. $s'(t)$
# B. $s''(t)$
# C. $\int s(t)\,dt$
# D. $|v(t)|$
#
# ---
#
# ### Question 4.
#
# If $v(t)=0$ at some time $t$, what must be true?
#
# A. The object is at rest at that moment
# B. The object is slowing down
# C. The object is speeding up
# D. The object is turning around
#
# ---
#
# ### Question 5.
#
# If $v(t)$ is positive and $a(t)$ is negative, the object is:
#
# A. Speeding up
# B. Slowing down
# C. Moving backward
# D. At rest
#
# ---
#
# ### Question 6.
# Displacement over $[a,b]$ is:
#
# A. $\int_a^b |v(t)|\,dt$
# B. $s(b)-s(a)$
# C. $\int_a^b a(t)\,dt$
# D. $v(b)-v(a)$
#
# ---
#
# ### Question 7.
# Total distance traveled over $[a,b]$ is:
#
# A. $s(b)-s(a)$
# B. $\int_a^b v(t)\,dt$
# C. $\int_a^b |v(t)|\,dt$
# D. $v(b)-v(a)$
#
# ---
#
# ### Question 8.
# If $s(t)$ is continuous on $[a,b]$ and differentiable on $(a,b)$, the Mean Value Theorem guarantees:
#
# A. $s'(t)=0$ somewhere
# B. $s'(c)=\dfrac{s(b)-s(a)}{b-a}$ for some $c\in(a,b)$
# C. $s(b)=s(a)$
# D. $s'(t)$ is constant
#
# ---
#
# ### Question 9.
# If $v(t)=3t^2$, then acceleration is:
#
# A. $3t^2$
# B. $6t$
# C. $9t^2$
# D. $t^3$
#
# ---
#
# ### Question 10.
# If $a(t)=0$ for all $t$, what must be true?
#
# A. Velocity is constant
# B. Position is constant
# C. Velocity is increasing
# D. Speed is zero
#
# ---
#
# ### Question 11.
# If $v(t)$ changes sign from positive to negative, the object:
#
# A. Speeds up
# B. Slows down
# C. Reverses direction
# D. Stops permanently
#
# ---
#
# ### Question 12.
# Average velocity on $[a,b]$ is:
#
# A. $\dfrac{s(b)-s(a)}{b-a}$
# B. $s'(c)$
# C. $\int_a^b v(t)\,dt$
# D. $|v(t)|$
#
# ---
#
# ### Question 13.
# If $v(t)=0$ and $a(t)\neq 0$, then:
#
# A. The object is moving
# B. The object is at rest but about to change motion
# C. The object is at rest and will stay at rest
# D. The object is moving backward
#
# ---
#
# ### Question 14.
# If $v(t)$ is negative and $a(t)$ is negative, the object is:
#
# A. Speeding up
# B. Slowing down
# C. Moving forward
# D. At rest
#
# ---
#
# ### Question 15.
# If $s(t)=t^3-6t$, when is the object at rest?
#
# A. When $t=0$ only
# B. When $t=2$ only
# C. When $t=-2$ only
# D. When $t=-2$ or $t=2$

# %% [markdown]
# ## Answer Key
#
# 1. B
# 2. B
# 3. B
# 4. A
# 5. B
# 6. B
# 7. C
# 8. B
# 9. B
# 10. A
# 11. C
# 12. A
# 13. B
# 14. A
# 15. D
