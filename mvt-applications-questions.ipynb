# %% [markdown]
# ## CLEP Practice Questions: Physical Applications of the Mean Value Theorem Generated by GPT 5.1
#
# ### Question 1.
#
# A car travels 90 miles in 1.5 hours. Which statement is guaranteed by the Mean Value Theorem?
#
# A. The car’s speed was always 60 mph
# B. The car’s speed was never 60 mph
# C. At some moment, the car’s instantaneous speed was exactly 60 mph
# D. The car’s acceleration was constant
#
# ---
#
# ### Question 2.
#
# Let $s(t)$ be the position of a particle. If $s(t)$ is continuous on $[0,4]$ and differentiable on $(0,4)$, which must be true?
#
# A. There exists $c\in(0,4)$ such that $s'(c)=\dfrac{s(4)-s(0)}{4}$
# B. $s'(t)$ is constant
# C. $s(4)=s(0)$
# D. $s'(c)=0$ for some $c\in(0,4)$
#
# ---
#
# ### Question 3.
#
# A water tank fills from 200 liters to 260 liters over 10 minutes. What does the MVT guarantee?
#
# A. The flow rate was always 6 L/min
# B. The flow rate was never 6 L/min
# C. At some moment, the instantaneous flow rate was 6 L/min
# D. The flow rate was constant
#
# ---
#
# ### Question 4.
#
# Let $Q(t)$ be the volume of fluid passing through a pipe. If $Q'(t)$ is bounded by $|Q'(t)|\le 5$, what must be true?
#
# A. $|Q(b)-Q(a)|\le 5|b-a|$
# B. $Q(b)-Q(a)=5(b-a)$
# C. $Q'(t)=5$ for some $t$
# D. $Q(t)$ is constant
#
# ---
#
# ### Question 5.
#
# Let $W(t)$ be the work done by a machine. Which statement follows from the MVT?
#
# A. Instantaneous power equals average power at some moment
# B. Instantaneous power is constant
# C. Work is linear in time
# D. Power is always increasing
#
# ---
#
# ### Question 6.
#
# A battery discharges from 1000 mAh to 850 mAh over 2 hours. What does the MVT guarantee?
#
# A. The current was always −75 mA
# B. The current was never −75 mA
# C. At some moment, the instantaneous current was −75 mA
# D. The current was constant
#
# ---
#
# ### Question 7.
#
# Let $T(t)$ be the temperature of a metal rod. If $T(0)=40^\circ$ C and $T(5)=55^\circ$ C, what must be true?
#
# A. $T'(t)=3$ for all $t$
# B. $T'(c)=3$ for some $c\in(0,5)$
# C. $T'(c)=0$ for some $c\in(0,5)$
# D. $T(t)$ is linear
#
# ---
#
# ### Question 8.
#
# A population grows from 500 to 620 over 4 years. What does the MVT guarantee?
#
# A. Instantaneous growth rate equals 30 at some moment
# B. Growth rate is constant
# C. Growth rate is zero at some moment
# D. Population is linear
#
# ---
#
# ### Question 9.
#
# Let $I(t)=Q'(t)$ be electric current. If charge increases by 12 coulombs over 3 seconds, what must be true?
#
# A. $I(t)=4$ for all $t$
# B. $I(c)=4$ for some $c\in(0,3)$
# C. $I(c)=0$ for some $c\in(0,3)$
# D. $I(t)$ is constant
#
# ---
#
# ### Question 10.
#
# A cyclist travels 24 miles in 2 hours. Which statement is guaranteed?
#
# A. Instantaneous speed equals 12 mph at some moment
# B. Speed was always 12 mph
# C. Speed was never 12 mph
# D. Acceleration was zero
#
# ---
#
# ### Question 11.
#
# Let $s(t)$ be position. If $|s'(t)|\le 20$, what must be true?
#
# A. $|s(b)-s(a)|\le 20|b-a|$
# B. $s'(t)=20$ for some $t$
# C. $s(b)-s(a)=20(b-a)$
# D. $s(t)$ is constant
#
# ---
#
# ### Question 12.
#
# A heating system raises a room from 60°F to 68°F in 30 minutes. What does the MVT guarantee?
#
# A. Instantaneous heating rate equals $\frac{8}{30}$ °F/min at some moment
# B. Heating rate is constant
# C. Heating rate is zero at some moment
# D. Temperature is linear
#
# ---
#
# ### Question 13.
#
# Let $P(t)$ be population. If $P'(t)\ge 0$ for all $t$, what must be true?
#
# A. Population is constant
# B. Population is decreasing
# C. Population is non‑decreasing
# D. Population is linear
#
# ---
#
# ### Question 14.
#
# A machine outputs 500 J of work in 10 seconds. What does the MVT guarantee?
#
# A. Instantaneous power equals 50 W at some moment
# B. Power was always 50 W
# C. Power was never 50 W
# D. Power was constant
#
# ---
#
# ### Question 15.
#
# Let $Q(t)$ be fluid volume. If $Q(2)=40$ and $Q(6)=100$, what must be true?
#
# A. $Q'(t)=15$ for all $t$
# B. $Q'(c)=15$ for some $c\in(2,6)$
# C. $Q'(c)=0$ for some $c\in(2,6)$
# D. $Q(t)$ is linear

# %% [markdown]
# ## Answer Key
#
# 1. C
# 2. A
# 3. C
# 4. A
# 5. A
# 6. C
# 7. B
# 8. A
# 9. B
# 10. A
# 11. A
# 12. A
# 13. C
# 14. A
# 15. B
